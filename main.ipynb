# %%
#test
# !python ./test.py
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'XLNetTokenizer'.
# The class this function is called from is 'KoBERTTokenizer'.
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# <<TEST>>
# 100%|███████████████████████████████████████| 1139/1139 [04:30<00:00,  4.21it/s]
# 	 <<FOLD1>> f1 [0.97609872 0.97609872]
# 100%|███████████████████████████████████████| 1139/1139 [04:31<00:00,  4.19it/s]
# 	 <<FOLD2>> f1 [0.98142907 0.98142907]
# ...

# %%
import pandas as pd
test = pd.read_csv('./data/Test_Part1.csv')

# %%
test.loc[0].content
# Out:
# '“4차산업혁명위원회는 정답을 내는 주체가 아니다. 정답을 찾아가는 과정에 대한 판을 깔아 주는 역할을 하려고 한다.”(장병규 4차산업위 위원장) 대통령 직속 4차산업혁명위원회(4차산업위)가 출범 4개월여 만에 규제혁신의 해법을 찾기 위한 첫 판을 깔았다.\n4차위는 21일부터 22일까지 1박2일 동안 강원도 원주 KT연수원에서 4차 산업혁명에 필요한 사회적 합의를 이끌어 내는 첫걸음으로 민간과 정부 이해당사자들이 참여한 가운데 △핀테크 △위치정보 △혁신의료기기 분야의 ‘규제혁신 초안’을 이끌어 내는 끝장토론 형식의 ‘규제·제도혁신 해커톤’을 개최했다.\n정해긴 기간 내에 집중토론을 통해 ‘프로토타입’을 만드는 ‘해커톤(hackathon)’은 민간과 정부가 함께 토론을 거쳐 규제혁신의 사회적 합의를 이끌어 내기 위한 새로운 토론 포맷으로 KT그룹의 ‘1등 워크샵’과 유사하다. 2014년 황창규 회장이 도입한 ‘1등 워크샵’은 1박2일간 끝장토론을 통해 결과를 도출하고 실행하는 경영 혁신 프로그램이다.\n◇장병규 위원장 “끝장토론서 개방형 집단이기주의가 편안하게 논의되길”= 4차산업위의 ‘규제·제도혁신 해커톤’ 기획을 총괄한 장병규 위원장은 이번 1박2일 간 민관이 함께하는 허심탄회한 토론을 거쳐 4차 산업혁명에 대비한 사회적 합의가 도출 될 수 있을 것으로 기대했다.\n장 위원장은 이날 인사말을 통해 “혁신성장은 민간이 주도하고 정부가 조력자의 역할을 해야 한다는 것이 이 정부의 기조”라며 “민간에서 가장 답답해하는 것이 경직된 규제”라고 강조했다.\n장 위원장은 “4차 산업혁명은 정부의 탑다운(Top-down) 식 계획경제로만 대응하기 어렵다. 민간에서 시작되는 바텀업(Bottom-up)도 병행돼야 한다”며 “정답을 바텀업으로 찾아가는 토론과정과 프로세스가 정부 정책 수립에 가미돼 같이 간다면 규제혁신이 속도를 낼 수 있다”고 밝혔다.\n그는 “4차위는 정답을 찾아가는 판을 깔아주기만 할 것”이라며 “프로토타입을 구하는 게 해커톤의 기본 정신이다. 제도 
# ...

# %%
# !python ./train_hand.py
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'XLNetTokenizer'.
# The class this function is called from is 'KoBERTTokenizer'.
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/rnn.py:82: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# <<TRAIN>>
#
# ==FOLD 1 || EPOCH 1/3==
# ...
# 100%|██████████████████████████████████████████| 25/25 [00:00<00:00, 115.67it/s]
# Train_loss : 0.69622878074646 || Train_acc : 0.5125
#  Val_loss : 0.7189520692825317 || Val_acc : 0.48
# Save the best params with val_loss:0.7190, val_acc:0.4800
#
# <<FOLD 1>>
# 	 Train loss 0.6962 | acc 0.5125
# 	 Valid loss 0.7190 | acc 0.4800
#
# ...
